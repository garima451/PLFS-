# %%
import pandas as pd
data = {
    "Year": ["2017-18", "2017-18", "2018-19", "2018-19", "2019-20", "2019-20", "2020-21", "2020-21",
             "2021-22", "2021-22", "2022-23", "2022-23", "2023-24", "2023-24"],
    "Age Group": ["15 years and above", "all ages"] * 7,
    "Rural Male": [76.4, 54.9, 76.4, 55.1, 77.9, 56.3, 78.1, 57.1, 78.2, 56.9, 80.2, 55.5, 80.2, 57.9],
    "Rural Female": [24.6, 18.2, 26.4, 19.7, 33.0, 24.7, 36.5, 27.7, 36.6, 27.2, 41.5, 30.5, 47.6, 35.5],
    "Rural Person": [50.7, 37.0, 51.5, 37.7, 55.5, 40.8, 57.4, 42.7, 57.5, 42.2, 60.8, 43.4, 63.7, 46.8],
    "Urban Male": [74.5, 57.0, 73.7, 56.7, 74.6, 57.8, 74.6, 58.4, 74.7, 58.3, 74.5, 58.3, 75.6, 59.0],
    "Urban Female": [20.4, 15.9, 20.4, 16.1, 23.3, 18.5, 23.2, 18.6, 23.8, 18.8, 25.4, 20.2, 28.0, 22.3],
    "Urban Person": [47.6, 36.8, 47.5, 36.9, 49.3, 38.6, 49.1, 38.9, 49.7, 39.0, 50.4, 39.8, 52.0, 41.0],
    "Total Male": [75.8, 55.5, 75.5, 55.6, 76.8, 56.8, 77.0, 57.5, 77.2, 57.3, 78.5, 56.2, 78.8, 58.2],
    "Total Female": [23.3, 17.5, 24.5, 18.6, 30.0, 22.8, 32.5, 25.1, 32.8, 24.8, 37.0, 27.8, 41.7, 31.7],
    "Total Person": [49.8, 36.9, 50.2, 37.5, 53.5, 40.1, 54.9, 41.6, 55.2, 41.3, 57.9, 42.4, 60.1, 45.1]
}
df = pd.DataFrame(data)
print(df)
# Out:
#        Year           Age Group  Rural Male  Rural Female  Rural Person  \
# 0   2017-18  15 years and above        76.4          24.6          50.7
# 1   2017-18            all ages        54.9          18.2          37.0
# 2   2018-19  15 years and above        76.4          26.4          51.5
# 3   2018-19            all ages        55.1          19.7          37.7
# 4   2019-20  15 years and above        77.9          33.0          55.5
# 5   2019-20            all ages        56.3          24.7          40.8
# 6   2020-21  15 years and above        78.1          36.5          57.4
# 7   2020-21            all ages        57.1          27.7          42.7
# 8   2021-22  15 years and above        78.2          36.6          57.5
# 9   2021-22            all ages        56.9          27.2          42.2
# 10  2022-23  15 years and above        80.2          41.5          60.8
# 11  2022-23            all ages        55.5          30.5          43.4
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df_15_plus = df[df['Age Group'] == '15 years and above']
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Total Male', data=df_15_plus, label='Male', marker='o')
sns.lineplot(x='Year', y='Total Female', data=df_15_plus, label='Female', marker='o')
sns.lineplot(x='Year', y='Total Person', data=df_15_plus, label='Total', marker='o')
plt.title('Labour Force Participation Rate Over the Years (15+ Age Group)', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Labour Force Participation Rate (%)')
plt.legend(title='Gender')
plt.grid(True)
plt.show()

# %% [markdown]
# Overall increase: LFPR grew from 49.8% in 2017-18 to 60.1% in 2023-24, indicating a consistent improvement.
#
# Male dominance: Male participation remains higher, but female participation is rising at a faster rate, closing the gender gap.
#
# Policy Implication: Policies promoting gender equality in employment are showing positive effects, but further initiatives are required.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='Total Male', data=df_15_plus, color='blue', label='Male')
sns.barplot(x='Year', y='Total Female', data=df_15_plus, color='pink', label='Female')
plt.title('Gender Disparity in Labour Force Participation', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Participation Rate (%)')
plt.legend(title='Gender')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Persistent gender gap: Male participation is significantly higher, although female participation has increased from 23.3% (2017-18) to 41.7% (2023-24).
#
# Policy Implication: Government initiatives focusing on women’s employment programs are necessary to reduce the gender gap.

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))
# Rural participation
ax[0].plot(df_15_plus['Year'], df_15_plus['Rural Male'], marker='o', label='Male', color='green')
ax[0].plot(df_15_plus['Year'], df_15_plus['Rural Female'], marker='o', label='Female', color='orange')
ax[0].plot(df_15_plus['Year'], df_15_plus['Rural Person'], marker='o', label='Total', color='blue')
ax[0].set_title('Rural LFPR (15+ Age Group)', fontsize=14)
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Participation Rate (%)')
ax[0].legend()
# Urban participation
ax[1].plot(df_15_plus['Year'], df_15_plus['Urban Male'], marker='o', label='Male', color='green')
ax[1].plot(df_15_plus['Year'], df_15_plus['Urban Female'], marker='o', label='Female', color='orange')
ax[1].plot(df_15_plus['Year'], df_15_plus['Urban Person'], marker='o', label='Total', color='blue')
ax[1].set_title('Urban LFPR (15+ Age Group)', fontsize=14)
ax[1].set_xlabel('Year')
ax[1].set_ylabel('Participation Rate (%)')
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Rural participation is consistently higher than urban participation, driven by agricultural jobs.
#
# Urban participation shows a slower but steady increase, indicating rising non-agricultural employment.
#
# Policy Implication: Urban job growth programs need to be enhanced, with special focus on women employment.

# %%
df_15_plus['YOY_Change'] = df_15_plus['Total Person'].pct_change() * 100
plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='YOY_Change', data=df_15_plus, palette='coolwarm')
plt.title('Year-over-Year Change in LFPR (%)', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Percentage Change (%)')
plt.grid(axis='y')
plt.show()
# Out:
# <ipython-input-23-767b800df293>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_15_plus['YOY_Change'] = df_15_plus['Total Person'].pct_change() * 100
# <ipython-input-23-767b800df293>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year', y='YOY_Change', data=df_15_plus, palette='coolwarm')

# %% [markdown]
# The largest growth was between 2021-22 and 2022-23, with a significant rise in participation.
#
# Positive YoY growth throughout the years highlights consistent economic recovery.
#
# Policy Implication: Continuous improvement in labour policies will strengthen future participation.

# %%
df_15_plus['Gender_Gap'] = df_15_plus['Total Male'] - df_15_plus['Total Female']
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Gender_Gap', data=df_15_plus, marker='o', color='red')
plt.title('Gender Gap in LFPR Over the Years', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Gender Gap (%)')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-24-0f89daf4a385>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_15_plus['Gender_Gap'] = df_15_plus['Total Male'] - df_15_plus['Total Female']

# %% [markdown]
# The gender gap reduced from 52.5% in 2017-18 to 37.1% in 2023-24, indicating gradual progress.
#
# Policy Implication: Targeted policies promoting female employment will further close the gender gap.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, axes = plt.subplots(2, 1, figsize=(16, 12))
# --- Box Plot ---
sns.boxplot(data=df_15_plus[['Rural Male', 'Rural Female', 'Rural Person',
                             'Urban Male', 'Urban Female', 'Urban Person',
                             'Total Male', 'Total Female', 'Total Person']],
            ax=axes[0], palette='coolwarm')

axes[0].set_title('LFPR Deviation by Region and Gender (15 Years and Above)', fontsize=18)
axes[0].set_ylabel('Labour Force Participation Rate (%)')
axes[0].set_xlabel('Category')
axes[0].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',
                         'Urban Male', 'Urban Female', 'Urban Person',
                         'Total Male', 'Total Female', 'Total Person'], rotation=45)
axes[0].grid(axis='y')
# --- Violin Plot ---
sns.violinplot(data=df_15_plus[['Rural Male', 'Rural Female', 'Rural Person',
                                'Urban Male', 'Urban Female', 'Urban Person',
                                'Total Male', 'Total Female', 'Total Person']],
               ax=axes[1], palette='viridis')

axes[1].set_title('LFPR Distribution by Region and Gender (15 Years and Above)', fontsize=18)
axes[1].set_ylabel('Labour Force Participation Rate (%)')
axes[1].set_xlabel('Category')
axes[1].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',
                         'Urban Male', 'Urban Female', 'Urban Person',
                         'Total Male', 'Total Female', 'Total Person'], rotation=45)
axes[1].grid(axis='y')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-25-b2fbab5dedbf>:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',
# <ipython-input-25-b2fbab5dedbf>:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',

# %% [markdown]
# Rural Female LFPR shows some low outliers, indicating occasional drops in female labor force participation.
#
# Total Female also shows occasional low outliers, suggesting volatility in female employment patterns.
#
# Urban Male and Urban Female have more compact distributions, suggesting less fluctuation in urban LFPR values.
#
# Male LFPR (both rural and urban) is consistently higher and less volatile compared to females.
#
# Female LFPR shows a larger spread and more outliers, indicating greater variability in female labor participation.
#
# This gender disparity highlights the consistently lower and more volatile female workforce participation, especially in rural areas.
#
# Rural Male LFPR shows higher participation but also some outliers, indicating occasional employment spikes or drops.
#
# Urban LFPR values are more stable, with fewer outliers and narrower distributions, indicating more consistent labor participation in urban areas.
#
# The urban population seems to have a steadier and less volatile labor participation trend.
#
# Urban Male and Urban Person have thicker violins around the median, indicating higher density (more consistent participation around the mean).
#
# Rural Female and Total Female violins are thinner and more spread out, suggesting greater variance and less consistency.
#
# Male distributions are more concentrated (thicker around the middle), indicating stability in male LFPR.
#
# Female distributions are wider, showing more fluctuation and inconsistency in female LFPR values.
#
# This reinforces the insight from the box plot: female LFPR is not only lower but also more unstable.
#
# The urban violin plots are generally narrower, indicating less fluctuation and more consistent LFPR values.
#
# Rural distributions are wider, reflecting higher LFPR volatility in rural areas, especially for females.

# %%
import pandas as pd

# Data for WPR Table (starting from lower years to higher years)
data = {
    'Year': [
        '2017-18', '2017-18',
        '2018-19', '2018-19',
        '2019-20', '2019-20',
        '2020-21', '2020-21',
        '2021-22', '2021-22',
        '2022-23', '2022-23',
        '2023-24', '2023-24'
    ],
    'Age Group': [
        '15 years and above', 'all ages',
        '15 years and above', 'all ages',
        '15 years and above', 'all ages',
        '15 years and above', 'all ages',
        '15 years and above', 'all ages',
        '15 years and above', 'all ages',
        '15 years and above', 'all ages'
    ],
    'Rural Male': [72.0, 51.7, 72.2, 52.1, 74.4, 53.8, 75.1, 54.9, 75.3, 54.7, 78.0, 54.0, 78.1, 56.3],
    'Rural Female': [23.7, 17.5, 25.5, 19.0, 32.2, 24.0, 35.8, 27.1, 35.8, 26.6, 40.7, 30.0, 46.5, 34.8],
    'Rural Person': [48.1, 35.0, 48.9, 35.8, 53.3, 39.2, 55.5, 41.3, 55.6, 40.8, 59.4, 42.3, 62.1, 45.6],
    'Urban Male': [69.3, 53.0, 68.6, 52.7, 69.9, 54.1, 70.0, 54.9, 70.4, 55.0, 71.0, 55.6, 72.3, 56.4],
    'Urban Female': [18.2, 14.2, 18.4, 14.5, 21.3, 16.8, 21.2, 17.0, 21.9, 17.3, 23.5, 18.7, 26.0, 20.7],
    'Urban Person': [43.9, 33.9, 43.9, 34.1, 45.8, 35.9, 45.8, 36.3, 46.6, 36.6, 47.7, 37.7, 49.4, 38.9],
    'Total Male': [71.2, 52.1, 71.0, 52.3, 73.0, 53.9, 73.5, 54.9, 73.8, 54.8, 76.0, 54.4, 76.3, 56.4],
    'Total Female': [22.0, 16.5, 23.3, 17.6, 28.7, 21.8, 31.4, 24.2, 31.7, 24.0, 35.9, 27.0, 40.3, 30.7],
    'Total Person': [46.8, 34.7, 47.3, 35.3, 50.9, 38.2, 52.6, 39.8, 52.9, 39.6, 56.0, 41.1, 58.2, 43.7]
}

# Create DataFrame
df_wpr = pd.DataFrame(data)

# Sort the DataFrame by Year


# Display the DataFrame
print(df_wpr)
# Out:
#        Year           Age Group  Rural Male  Rural Female  Rural Person  \
# 0   2017-18  15 years and above        72.0          23.7          48.1
# 1   2017-18            all ages        51.7          17.5          35.0
# 2   2018-19  15 years and above        72.2          25.5          48.9
# 3   2018-19            all ages        52.1          19.0          35.8
# 4   2019-20  15 years and above        74.4          32.2          53.3
# 5   2019-20            all ages        53.8          24.0          39.2
# 6   2020-21  15 years and above        75.1          35.8          55.5
# 7   2020-21            all ages        54.9          27.1          41.3
# 8   2021-22  15 years and above        75.3          35.8          55.6
# 9   2021-22            all ages        54.7          26.6          40.8
# 10  2022-23  15 years and above        78.0          40.7          59.4
# 11  2022-23            all ages        54.0          30.0          42.3
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df_wpr_15_plus = df_wpr[df_wpr['Age Group'] == '15 years and above']
fig, ax = plt.subplots(1, 2, figsize=(18, 7))


# Box plot
sns.boxplot(data=df_wpr_15_plus[['Rural Male', 'Rural Female', 'Rural Person',
                                 'Urban Male', 'Urban Female', 'Urban Person',
                                 'Total Male', 'Total Female', 'Total Person']],
            ax=ax[0], palette='pastel')

ax[0].set_title('WPR Distribution by Region and Gender (15+ years)')
ax[0].set_xlabel('Region and Gender')
ax[0].set_ylabel('WPR (%)')
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=45)

# Violin plot
sns.violinplot(data=df_wpr_15_plus[['Rural Male', 'Rural Female', 'Rural Person',
                                    'Urban Male', 'Urban Female', 'Urban Person',
                                    'Total Male', 'Total Female', 'Total Person']],
               ax=ax[1], palette='muted')

ax[1].set_title('WPR Violin Plot by Region and Gender (15+ years)')
ax[1].set_xlabel('Region and Gender')
ax[1].set_ylabel('WPR (%)')
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-5bdb99527d60>:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=45)
# <ipython-input-5-5bdb99527d60>:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45)

# %% [markdown]
# The median WPR (Worker Population Ratio) is consistently higher for males across all regions (rural, urban, and combined) compared to females.
#
# The overall WPR distribution for males is more stable and concentrated, indicating less fluctuation over the years.
#
# For females, the distribution is wider, suggesting more variability and gradual growth over the years.
#
# The violin plot shows a gradual upward shift in female WPR values, indicating improving female workforce participation over time.
#
# However, the spread is larger for females, reflecting more year-on-year variability.
#
# Rural WPR is generally higher than urban WPR for both males and females.
#
# The violin plot shows narrower distributions for urban WPR, indicating less fluctuation in urban employment patterns.
#
# Rural areas show a broader distribution, implying more year-to-year variability in workforce participation.
#
# The combined WPR distribution is more stable and symmetric, reflecting the steady rise in workforce participation over the years.
#
# The box plot shows a noticeable upward shift in the median, highlighting the overall improvement in employment rates.
#
# There are no significant outliers, indicating a relatively consistent growth trend.
#
# The violin plot highlights a wider spread for females, which may indicate employment fluctuations due to socio-economic factors or policy changes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Total Male', data=df_wpr_15_plus, label='Male', marker='o')
sns.lineplot(x='Year', y='Total Female', data=df_wpr_15_plus, label='Female', marker='o')
sns.lineplot(x='Year', y='Total Person', data=df_wpr_15_plus, label='Total', marker='o')

plt.title('Worker Population Ratio Over the Years (15+ Age Group)', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Worker Population Ratio')
plt.legend(title='Gender')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))

sns.barplot(x='Year', y='Total Male', data=df_wpr_15_plus, color='blue', label='Male')
sns.barplot(x='Year', y='Total Female', data=df_wpr_15_plus, color='pink', label='Female')

plt.title('Gender Disparity in Worker Polpulation Ratio', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Population Ratio')
plt.legend(title='Gender')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Rural participation
ax[0].plot(df_wpr_15_plus['Year'], df_wpr_15_plus['Rural Male'], marker='o', label='Male', color='green')
ax[0].plot(df_wpr_15_plus['Year'], df_wpr_15_plus['Rural Female'], marker='o', label='Female', color='orange')
ax[0].plot(df_wpr_15_plus['Year'], df_wpr_15_plus['Rural Person'], marker='o', label='Total', color='blue')
ax[0].set_title('Rural WPR (15+ Age Group)', fontsize=14)
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Population Ratio')
ax[0].legend()

# Urban participation
ax[1].plot(df_wpr_15_plus['Year'], df_wpr_15_plus['Urban Male'], marker='o', label='Male', color='green')
ax[1].plot(df_wpr_15_plus['Year'], df_wpr_15_plus['Urban Female'], marker='o', label='Female', color='orange')
ax[1].plot(df_wpr_15_plus['Year'], df_wpr_15_plus['Urban Person'], marker='o', label='Total', color='blue')
ax[1].set_title('Urban WPR (15+ Age Group)', fontsize=14)
ax[1].set_xlabel('Year')
ax[1].set_ylabel('Population Ratio')
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
df_wpr_15_plus['YOY_Change'] = df_wpr_15_plus['Total Person'].pct_change() * 100

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='YOY_Change', data=df_wpr_15_plus, palette='coolwarm')

plt.title('Year-over-Year Change in WPR (%)', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Percentage Change (%)')
plt.grid(axis='y')
plt.show()
# Out:
# <ipython-input-46-bc8b2200e736>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wpr_15_plus['YOY_Change'] = df_wpr_15_plus['Total Person'].pct_change() * 100
# <ipython-input-46-bc8b2200e736>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year', y='YOY_Change', data=df_wpr_15_plus, palette='coolwarm')

# %%
df_wpr_15_plus['Gender_Gap'] = df_wpr_15_plus['Total Male'] - df_wpr_15_plus['Total Female']

plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Gender_Gap', data=df_wpr_15_plus, marker='o', color='red')

plt.title('Gender Gap in WPR Over the Years', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Gender Gap (%)')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-49-0b8f8a9aee34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wpr_15_plus['Gender_Gap'] = df_wpr_15_plus['Total Male'] - df_wpr_15_plus['Total Female']

# %%
import pandas as pd

# Creating the Unemployment Rate dataframe with both age groups
data_ur = {
    'Year': [2017, 2018, 2019, 2020, 2021, 2022, 2023] * 2,
    'Age Group': ['15 years and above'] * 7 + ['All ages'] * 7,
    'Rural Male': [5.7, 5.5, 4.5, 3.8, 3.8, 2.7, 2.7,
                   5.8, 5.6, 4.5, 3.9, 3.8, 2.8, 2.7],
    'Rural Female': [3.8, 3.5, 2.6, 2.1, 2.1, 1.8, 2.1,
                     3.8, 3.5, 2.6, 2.1, 2.1, 1.8, 2.1],
    'Rural Person': [5.3, 5.0, 3.9, 3.3, 3.2, 2.4, 2.5,
                     5.3, 5.0, 4.0, 3.3, 3.3, 2.4, 2.5],
    'Urban Male': [6.9, 7.0, 6.4, 6.1, 5.8, 4.7, 4.4,
                   7.1, 7.1, 6.4, 6.1, 5.8, 4.7, 4.4],
    'Urban Female': [10.8, 9.8, 8.9, 8.6, 7.9, 7.5, 7.1,
                      10.8, 9.9, 8.9, 8.6, 7.9, 7.5, 7.1],
    'Urban Person': [7.7, 7.6, 6.9, 6.7, 6.3, 5.4, 5.1,
                     7.8, 7.7, 7.0, 6.7, 6.3, 5.4, 5.1],
    'Total Male': [6.1, 6.0, 5.0, 4.5, 4.4, 3.3, 3.2,
                   6.2, 6.0, 5.1, 4.5, 4.4, 3.3, 3.2],
    'Total Female': [5.6, 5.1, 4.2, 3.5, 3.3, 2.9, 3.2,
                     5.7, 5.2, 4.2, 3.5, 3.3, 2.9, 3.1],
    'Total Person': [6.0, 5.8, 4.8, 4.2, 4.1, 3.2, 3.2,
                     6.2, 5.8, 4.8, 4.2, 4.1, 3.2, 3.2]
}

# Converting into a DataFrame
df_ur = pd.DataFrame(data_ur)

# Display the dataframe
print(df_ur)
# Out:
#     Year           Age Group  Rural Male  Rural Female  Rural Person  \
# 0   2017  15 years and above         5.7           3.8           5.3
# 1   2018  15 years and above         5.5           3.5           5.0
# 2   2019  15 years and above         4.5           2.6           3.9
# 3   2020  15 years and above         3.8           2.1           3.3
# 4   2021  15 years and above         3.8           2.1           3.2
# 5   2022  15 years and above         2.7           1.8           2.4
# 6   2023  15 years and above         2.7           2.1           2.5
# 7   2017            All ages         5.8           3.8           5.3
# 8   2018            All ages         5.6           3.5           5.0
# 9   2019            All ages         4.5           2.6           4.0
# 10  2020            All ages         3.9           2.1           3.3
# 11  2021            All ages         3.8           2.1           3.3
# 12  2022            All ages         2.8           1.8           2.4
# ...

# %%
# prompt: plot box plot and violin plot on the basis of this data
df_ur_15_plus = df_ur[df_ur['Age Group'] == '15 years and above']

import matplotlib.pyplot as plt
# Setting the figure size
fig, axes = plt.subplots(2, 1, figsize=(16, 12))

# --- Box Plot ---
sns.boxplot(data=df_ur_15_plus[['Rural Male', 'Rural Female', 'Rural Person',
                             'Urban Male', 'Urban Female', 'Urban Person',
                             'Total Male', 'Total Female', 'Total Person']],
            ax=axes[0], palette='coolwarm')

axes[0].set_title('Unemployment Rate Deviation by Region and Gender', fontsize=18)
axes[0].set_ylabel('Unemployment Rate (%)')
axes[0].set_xlabel('Category')
axes[0].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',
                         'Urban Male', 'Urban Female', 'Urban Person',
                         'Total Male', 'Total Female', 'Total Person'], rotation=45)
axes[0].grid(axis='y')

# --- Violin Plot ---
sns.violinplot(data=df_ur_15_plus[['Rural Male', 'Rural Female', 'Rural Person',
                                'Urban Male', 'Urban Female', 'Urban Person',
                                'Total Male', 'Total Female', 'Total Person']],
               ax=axes[1], palette='viridis')

axes[1].set_title('Unemployment Rate Distribution by Region and Gender', fontsize=18)
axes[1].set_ylabel('Unemployment Rate (%)')
axes[1].set_xlabel('Category')
axes[1].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',
                         'Urban Male', 'Urban Female', 'Urban Person',
                         'Total Male', 'Total Female', 'Total Person'], rotation=45)
axes[1].grid(axis='y')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-8007fb046575>:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',
# <ipython-input-16-8007fb046575>:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',

# %% [markdown]
# Urban Female Unemployment: Urban females face the highest unemployment rates and exhibit greater variability compared to other categories. This suggests that specific factors may be contributing to their higher unemployment levels in urban settings.
#
# Rural-Urban Disparity: Unemployment rates are generally lower in rural areas than in urban areas. This could be attributed to differences in economic activities and employment opportunities.
#
# Gender Disparity: A clear gender gap exists in unemployment rates, with females experiencing higher unemployment than males. This disparity persists across both rural and urban areas.
#
# Stability of Unemployment: Male unemployment rates tend to be more stable over time, while female unemployment rates show greater variability. This suggests that policies aimed at reducing unemployment may need to be tailored differently for males and females.

# %%
df_ur_15_plus = df_ur[df_ur['Age Group'] == '15 years and above']


plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Total Male', data=df_ur_15_plus, label='Male', marker='o')
sns.lineplot(x='Year', y='Total Female', data=df_ur_15_plus, label='Female', marker='o')
sns.lineplot(x='Year', y='Total Person', data=df_ur_15_plus, label='Total', marker='o')

plt.title('Unemployment Rate Over the Years (15+ Age Group)', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
plt.legend(title='Gender')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))

sns.barplot(x='Year', y='Total Male', data=df_ur_15_plus, color='blue', label='Male')
sns.barplot(x='Year', y='Total Female', data=df_ur_15_plus, color='pink', label='Female')

plt.title('Gender Disparity in Unemployment Rate', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Participation Rate (%)')
plt.legend(title='Gender')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Rural participation
ax[0].plot(df_ur_15_plus['Year'], df_ur_15_plus['Rural Male'], marker='o', label='Male', color='green')
ax[0].plot(df_ur_15_plus['Year'], df_ur_15_plus['Rural Female'], marker='o', label='Female', color='orange')
ax[0].plot(df_ur_15_plus['Year'], df_ur_15_plus['Rural Person'], marker='o', label='Total', color='blue')
ax[0].set_title('Rural Unemployment Rate (15+ Age Group)', fontsize=14)
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Unemployment Rate')
ax[0].legend()

# Urban participation
ax[1].plot(df_ur_15_plus['Year'], df_ur_15_plus['Urban Male'], marker='o', label='Male', color='green')
ax[1].plot(df_ur_15_plus['Year'], df_ur_15_plus['Urban Female'], marker='o', label='Female', color='orange')
ax[1].plot(df_ur_15_plus['Year'], df_ur_15_plus['Urban Person'], marker='o', label='Total', color='blue')
ax[1].set_title('Urban Unemployment Rate (15+ Age Group)', fontsize=14)
ax[1].set_xlabel('Year')
ax[1].set_ylabel('Unemployment Rate')
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
df_ur_15_plus['YOY_Change'] = df_ur_15_plus['Total Person'].pct_change() * 100

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='YOY_Change', data=df_ur_15_plus, palette='coolwarm')

plt.title('Year-over-Year Change in UR (%)', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Percentage Change (%)')
plt.grid(axis='y')
plt.show()
# Out:
# <ipython-input-55-2ac8f324aff0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ur_15_plus['YOY_Change'] = df_ur_15_plus['Total Person'].pct_change() * 100
# <ipython-input-55-2ac8f324aff0>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year', y='YOY_Change', data=df_ur_15_plus, palette='coolwarm')

# %%
import matplotlib.pyplot as plt
# Setting the figure size
fig, axes = plt.subplots(2, 1, figsize=(16, 12))

# --- Box Plot ---
sns.boxplot(data=df_ur_15_plus[['Rural Male', 'Rural Female', 'Rural Person',
                             'Urban Male', 'Urban Female', 'Urban Person',
                             'Total Male', 'Total Female', 'Total Person']],
            ax=axes[0], palette='coolwarm')

axes[0].set_title('Unemployment Rate Deviation by Region and Gender', fontsize=18)
axes[0].set_ylabel('Unemployment Rate (%)')
axes[0].set_xlabel('Category')
axes[0].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',
                         'Urban Male', 'Urban Female', 'Urban Person',
                         'Total Male', 'Total Female', 'Total Person'], rotation=45)
axes[0].grid(axis='y')

# --- Violin Plot ---
sns.violinplot(data=df_ur_15_plus[['Rural Male', 'Rural Female', 'Rural Person',
                                'Urban Male', 'Urban Female', 'Urban Person',
                                'Total Male', 'Total Female', 'Total Person']],
               ax=axes[1], palette='viridis')

axes[1].set_title('Unemployment Rate Distribution by Region and Gender', fontsize=18)
axes[1].set_ylabel('Unemployment Rate (%)')
axes[1].set_xlabel('Category')
axes[1].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',
                         'Urban Male', 'Urban Female', 'Urban Person',
                         'Total Male', 'Total Female', 'Total Person'], rotation=45)
axes[1].grid(axis='y')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-57-322951214843>:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',
# <ipython-input-57-322951214843>:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(['Rural Male', 'Rural Female', 'Rural Person',
